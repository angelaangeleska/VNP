# %% [markdown]
# # Requirements

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

# %% [markdown]
# # Configuration

# %%
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

# %% [markdown]
# # Simple Usage

# %%
# Initialize the webdriver.
browser = webdriver.Chrome()

# %%
# Navigate to a web page.
browser.get('https://finance.yahoo.com/crypto')

# %%
# Print the page source code.
print(browser.page_source)
# Out:
# <html lang="en-US" theme="light" data-color-scheme="light" class="desktop neo-green dock-upscale"><head><script type="text/javascript" async="" src="https://static.criteo.net/js/ld/publishertag.prebid.144.js"></script><script charset="UTF-8" type="text/javascript" async="async" src="https://cdn.taboola.com/libtrc/google-topics-api.20241104-8-RELEASE.es6.js"></script><script charset="UTF-8" type="text/javascript" src="https://cdn.taboola.com/libtrc/impl.20241104-8-RELEASE.js"></script><script type="text/javascript" src="//gum.criteo.com/sync?c=72&amp;r=2&amp;j=TRC.getRTUS&amp;us_privacy=1---&amp;gdpr=0&amp;gdpr_consent=&amp;gdpr_pd="></script><script type="text/javascript" src="https://cdn.taboola.com/scripts/eid.es5.js" crossorigin="anonymous" async="async"></script><script type="text/javascript" src="https://cdn.taboola.com/scripts/cds-pips.js" crossorigin="anonymous" async="async"></script><script type="text/javascript" src="https://cdn.taboola.com/scripts/cwc.es5.js" crossorigin="anonymous" async="async"></script><script type="text/javascript" async="" src="//pm-widget.taboola.com/yahooweb-network/load.js"></script>
#         <meta charset="utf-8">
#         <meta name="oath:guce:consent-host" content="guce.yahoo.com">
#         <link rel="preconnect" href="//s.yimg.com" crossorigin="anonymous"><link rel="preconnect" href="//geo.yahoo.com"><link rel="preconnect" href="//query1.finance.yahoo.com"><link rel="preconnect" href="//query2.finance.yahoo.com"><link rel="preconnect" href="//consent.cmp.oath.com"><link rel="preload" href="/__rapidworker-1.2.js" as="worker"><link rel="preconnect" href="https://s.yimg.com/uc/finance/webcore/js/_staticFinProtobuf.4b1559b8e4645fd93a12.js"><link rel="preconnect" href="https://cdn.jsdelivr.net/npm/protobufjs@7.1.2/dist/minimal/protobuf.min.js"><script>window.finNeoPageStart = Date.now();</script><script>(function(){if(!window.YAHOO){window.YAHOO={}}; window.YAHOO.context={"consent":{"allowContentPersonalization":true,"allowCrossDeviceMapping":true,"allowFirstPartyAds":true,"allowSellPersonalInfo":true,"canEmbedThirdPartyContent":true,"canSell":true,"consentedVendors":[],"allowAds":true,"allowOnlyLimitedAds":false,"rejectedAllConsent":false,"allowOnlyNonPersonalizedAds":false},"authed":"0","ynet":"0","ssl":"1","spdy":"0","ytee":"0","mode":"normal","tpConsent":true,"site":"finance","adblock":"0","bucket":["rocket_GA_desk_test-3-v1","ypf-commerce-widget-experiment-v2-q4","yf-us-genai-test-takeaway-collpase","yf-portfoliodetail-experiment","yf-advchart-tdv2"],"colo":"ir2","device":"desktop","bot":"0","browser":"chrome","app":"unknown","ecma":"modern","environment":"prod","gdpr":false,"lang":"en-US","dir":"ltr","intl":"us","network":"mobile","os":"windows nt","partner":"none","region":"US","time":1730850136046,"tz":"Europe/Belgrade","usercountry":"MK","rmp":"0","webview":"0","feature":["disableServiceRewrite","enableAnalystRatings","enableBankrateModalAd","enableChartbeat","enableChatSupport","enableCollapsibleHoldings","enableCompare","enableCompareConvertCurrency","enableConsentAndGTM","enableCurrencyConverter","enableDockAddToFollowing","enableDockCondensedHeader","enableDockNeoOptoutLink","enableDockPortfolioControl","enableExperimentalDockModules","enableLazyQSP","enableLiveBlogStatus","enableMarketsHub","enabledMonetizedLandingPages","enableNeoArticle","enableNeoBasicPFs","enableNeoGreen","enableNeoHouseCalcPage","enableNeoMortgageCalcPage","enableNeoOptOut","enableNeoPortfolioDetail","enableNeoQSPReportsLeaf","enablePersonalFinanceArticleReadMoreAlgo","enablePersonalFinanceNewsletterIntegration","enablePersonalFinanceZillowIntegration","enablePf2SubsSpotlight","enablePfLandingP2","enablePfPremium","enablePfPremiumRisk","enablePfStreaming","enablePinholeScreenshotOGForQuote","enablePlus","enablePortalStockStory","enableQSPChartNewShading","enableQSPChartRangeTooltips","enableQSPEarningsVsRev","enableQSPHistoryPlusDownload","enableQSPNavIcon","enableQuoteLookup","enableRecentQuotes","enableResearchHub","enableScreenerRedesign","enableSECFiling","enableSigninBeforeCheckout","enableSmartAssetMsgA","enableStockStoryPfPage","enableTradeNow","enableCompareFeatures","enableFinancePremiumArticle","enableGenericHeatMap","enableL2L3AB","enableMarketsLeafHeatMap","enableQSPIndustryHeatmap","enableStatusBadge","enableRapidClientOnlyPageView","enableRocketOptIn","enableCommerceDisableBankrateHYSAWidgets","enableFinanceWidgets","enablePfDetailSummaryTab"],"isDebug":false,"isForScreenshot":false,"isWebview":false,"theme":"light","pnrID":"","areAdsEnabled":true,"ccpa":{"warning":"","footerSequence":["terms_and_privacy","dashboard"],"links":{"dashboard":{"url":"https://guce.yahoo.com/privacy-dashboard?locale=en-US","label":"Privacy Dashboard"},"terms_and_privacy":{"multiurl":true,"label":"${terms_link}Terms${end_link} and ${privacy_link}Privacy Policy${end_link}","urls":{"terms_link":"https://guce.yahoo.com/terms?locale=en-US","privacy_link":"https://guce.yahoo.com/privacy-policy?locale=en-US"}}}},"yrid":"7t625dhjilbao","user":{"age":-2147483648,"crumb":"7KOI0CecjeE","firstName":null,"gender":"","year":0}};})();</script><script>function initFinSearch(){window.FinSearch?.init({uiConfig:{isSearchRedesign: true, isNeoGreen: tru ...
#             function _nimbusSendEVLoadEvent() {
#                 if (_nimbusEvLoad._player){
#                     window.finNeoEVReady = Date.now();
#                     window.dispatchEvent(new CustomEvent('NIMBUS_EV_READY',{detail: {}}));
#                 }
#             }
#             function onNimbusEVPlayerReady(){_nimbusEvLoad._player = true;_nimbusSendEVLoadEvent();}</script><script type="module">if(!window.finWebCore){window.finWebCore=function r(e){const{isModern:t=!0,isDev:i=!1,lang:a=s,devAssets:o,prodAssets:r,crumb:n="",features:c=[],strings:d}=e;let f={};const m=a.substring(a.lastIndexOf("-")+1);return{crumb:n,lang:a,region:m,features:c,store:{},intl:m.toLowerCase(),strings:d,assets:i?o:r,addScriptTag(e,s,t){if(!e)return;const i=document.createElement("script");i.setAttribute("src",e),i.setAttribute("type","text/javascript"),"function"==typeof t&&(i.onload=()=>{t(!0)},i.onerror=()=>{t(!1)});for(const e in s)e&&Object.prototype.hasOwnProperty.call(s,e)&&void 0!==s[e]&&i.setAttribute(e,s[e]);document.body.appendChild(i)},addAsset(e,s={}){const{async:a=!0,defer:n,useModule:c=!1,callback:d}=s;if(f[e])return void("function"==typeof d&&d(!0));let m;if(m=i?o:r,!m||0===m.length)return;f[e]=!0;let u=m[0]&&m[0][e]&&m[0][e].mjs;c?(this.addScriptTag(u,{async:a,defer:n,type:"module"},d),m.length>1&&!i&&(u=m[1]&&m[1][e]&&m[1][e].js,this.addScriptTag(u,{async:a,defer:n,nomodule:!0},d))):(m.length>1&&!t&&(u=m[1]&&m[1][e]&&m[1][e].js),this.addScriptTag(u,{async:a,defer:n},d))},reset(){f={}}}}({isModern:true,isDev:false,lang:'en-US',features:[],devAssets:{},prodAssets:[{"_staticFinProtobuf":{"mjs":"https://s.yimg.com/uc/finance/webcore/js/_staticFinProtobuf.4b1559b8e4645fd93a12
css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/83.F1CMla6e.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/MarketsTableWrapper.DgueLgcb.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/DataTable.BfIAkB7z.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/PortfolioSymbolCount.kJyivz1D.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/StatusTag.DUXJURWT.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/SparklineCell.CIg-TaAZ.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/DateCell.pMjzS6-j.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/Ticker.BCFDvICn.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/PortfolioDelete.B5XMj64G.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/PortfolioGainAndPercent.CW-5SiQK.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/PortfolioDeleteMessage.Cw8es2Sk.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/Rating.CHC3aCnG.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/StarRating.W01gA9Qm.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/DataTablePagination.lDuKHVf0.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/GradientScale.BwfNrsj8.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/SectionHeader.B9ETuNQk.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/LeafNewsStream.5uLOVnax.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/StoryStream.CkY57iKJ.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/StoryItem.D3WwxgQz.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/StoryMetaPublishing.uqjoCQC9.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/DynamicNativeAd.CBkjpegG.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/SkeletonLoader.YZvit63q.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/NoContent.Dkv6jm1i.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/SectionWithSidebar.Bf-AwOOu.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/MarketsHeatmap.D2uTipvq.css" rel="stylesheet">
# 		<link href="../../../assets/_app/immutable/assets/HeatMap.v9WG23fw.css" rel="stylesheet"><title>Crypto Currencies: prices, changes, trading volume &amp; daily charts - Yahoo Finance</title><!-- HTML_TAG_START --><!-- HTML_TAG_END --><!-- HTML_TAG_START --><!-- HTML_TAG_END --><link rel="manifest" href="/manifest.webmanifest"><script id="nimbus-benji-config" type="application/json">{"setting":{"refresh":{"duration":30,"requireUserAction":false,"limit":30,"tabFocus":{"outOfFocusDuration":3},"sameSizeRefresh":true,"reserved":{"duration":60}},"lazyLoad":false,"tracking":{"performance":true,"metrics":true},"taboolaSetting":{"pageType":"category","publisherId":"yahooweb-network"},"consent":{"allowOnlyLimitedAds":false,"allowOnlyNonPersonalizedAds":false},"userInfo":{"age":-2147483648,"gender":""}},"event":{"initRender":"DOMContentLoaded"},"feature":{"enableAdCollapse":true,"enableAdStacking":true},"positions":{"sda-E2E":{"id":"sda-E2E","path":"/22888152279/us/yfin/screen/dt/us_yfin_screen_dt_top_center","region":"index","size":[[3,1],[728,90]],"kvs":{"loc":"top_center"},"customSizeConfig":{"Horizon":true}}},"page":"markets","device":"tablet","i13n":{"colo":"ir2","lang":"en-US","mrkt":"us","navtype":"server","site":"finance","ver":"nimbus","abk":"0","auth_state":"signed_out","partner":"none","pct":"screener","pstcat":"crypto","pt":"utility","pg_name":"all","spaceid":"1183331958","consent":{"allowContentPersonalization":true,"allowCrossDeviceMapping":true,"allowFirstPartyAds":true,"allowSellPersonalInfo":true,"canEmbedThirdPartyContent":true,"canSell":true,"consentedVendors":[],"allowAds":true,"allowOnlyLimitedAds":false,"rejectedAllConsent":false,"allowOnlyNonPersonalizedAds":false},"authed":"0","ynet":"0","ssl":"1","spdy":"0","ytee":"0","mode":"normal","tpConsent":true,"adblock":"0","bucket":["rocket_GA_desk_test-3-v1","ypf-commerce-widget-experiment-v2-q4","yf-us-genai-test-takeaway-collpase","yf-portfoliodetail-experiment","yf-advchart-tdv2"],"device":"desktop","bot":"0","browser":"chrome","app":"unknown","ecma":"modern","environment":"prod","gdpr":false,"dir":"ltr","intl":"us","network":"mobile","os":"windows nt","region":"US","time":1730850136046,"tz":"Europe/Belgrade","usercountry":"MK","rmp":"0","webview":"0","feature":["disableServiceRewrite","enableAnalystRatings","enableBankrateModalAd","enableChartbeat","enableChatSupport","enableCollapsibleHoldings","enableCompare","enableCompareConvertCurrency","enableConsentAndGTM","enableCurrencyConverter","enableDockAddToFollowing","enableDockCondensedHeader","enableDockNeoOptoutLink","enableDockPortfolioControl","enableExperimentalDockModules","enableLazyQSP","enableLiveBlogStatus","enableMarketsHub","enabledMonetizedLandingPages","enableNeoArticle","enableNeoBasicPFs","enableNeoGreen","enableNeoHouseCalcPage","enableNeoMortgageCalcPage","enableNeoOptOut","enableNeoPortfolioDetail","enableNeoQSPReportsLeaf","enablePersonalFinanceArticleReadMoreAlgo","enablePersonalFinanceNewsletterIntegration","enablePersonalFinanceZillowIntegration","enablePf2SubsSpotlight","enablePfLandingP2","enablePfPremium","enablePfPremiumRisk","enablePfStreaming","enablePinholeScreenshotOGForQuote","enablePlus","enablePortalStockStory","enableQSPChartNewShading","enableQSPChartRangeTooltips","enableQSPEarningsVsRev","enableQSPHistoryPlusDownload","enableQSPNavIcon","enableQuoteLookup","enableRecentQuotes","enableResearchHub","enableScreenerRedesign","enableSECFiling","enableSigninBeforeCheckout","enableSmartAssetMsgA","enableStockStoryPfPage","enableTradeNow","enableCompareFeatures","enableFinancePremiumArticle","enableGenericHeatMap","enableL2L3AB","enableMarketsLeafHeatMap","enableQSPIndustryHeatmap","enableStatusBadge","enableRapidClientOnlyPageView","enableRocketOptIn","enableCommerceDisableBankrateHYSAWidgets","enableFinanceWidgets","enablePfDetailSummaryTab"],"isDebug":false,"isForScreenshot":false,"isWebview":false,"theme":"light","pnrID":"","areAdsEnabled":true,"ccpa":{"warning":"","footerSequence":[ ...
# </script>
#     <style>/* Sprites */
# #spchp.permission-guide .guide .microphone .sprite,
# #spchp .close-button,
# #spch .close-button,
# #spch .spchc .microphone,
# #spch .spchc .speaking .microphone {
#     background-image: url("https://s.yimg.com/pv/static/img/voiceSearch1x-1620383531565.min.png");
#     background-repeat: no-repeat;
#     background-size: initial;
#     color: transparent;
# }
# /* Retina displays */
# @media
#         only screen and (min-device-pixel-ratio: 2),
#         only screen and (-webkit-min-device-pixel-ratio: 2),
#         only screen and (min-resolution: 192dpi),
#         only screen and (min-resolution: 2dppx) {
# #spchp.permission-guide .guide .microphone .sprite,
# #spchp .close-button,
# #spch .close-button,
# #spch .spchc .microphone,
# #spch .spchc .speaking .microphone {
#         background-size: 41px 330px;
#         background-image: url("https://s.yimg.com/pv/static/img/voiceSearch2x-1620383531565.min.png")
# }
#     }
#
# /* permission guide */
# #spchp.permission-guide {
#     height: 100%;
#     width: 100%;
#     padding: 0;
#     opacity: 0.9;
#     background-color: #fff;
#     left: 0;
#     overflow: hidden;
#     position: fixed;
#     text-align: left;
#     top: 0;
#     z-index: 10000;
#     transition: visibility 0s linear 0.218s, background-color 0.218s;
# }
# #spchp.permission-guide .close-button {
#         background-position: 0 0;
#         width: 24px;
#         height: 24px;
#         border: none;
#         cursor: pointer;
#         right: 0;
#         margin: 20px;
#         padding: 0;
#         position: absolute;
#         top: 0;
#         z-index: 10;
#         opacity: 0.8;
#     }
# #spchp.permission-guide .close-button:hover {
#             opacity: 1;
#         }
# #spchp.permission-guide .guide {
#         margin: 191px 0 0 507px;
#     }
# #spchp.permission-guide .guide .microphone {
#             height: 68px;
#             width: 52px;
#             border-right: 1px solid #232a31;
#             float: left;
#         }
# #spchp.permission-guide .guide .microphone .sprite {
#                 background-position: 0 -105px;
#                 width: 28px;
#                 height: 28px;
#             }
# #spchp.permission-guide .guide .guide-text {
#             height: 68px;
#             margin-left: 24px;
#             float: left;
#         }
# #spchp.permission-guide .guide .guide-text .title {
#                 color: #232a31;
#                 font-size: 32px;
#                 font-family: HelveticaNeue-Bold;
#                 line-height: 28px;
#                 margin-bottom: 16px;
#             }
# #spchp.permission-guide .guide .guide-text .text {
#                 color: #232a31;
#                 font-size: 16px;
#                 line-height: 28px;
#             }
# #spchp.permission-guide.hide {
#         display: none;
#     }
#
# /* speech panel */
# #spch.spch {
#     background: #fff;
#     height: 100%;
#     left: 0;
#     opacity: 0;
#     overflow: hidden;
#     position: fixed;
#     text-align: left;
#     top: 0;
#     visibility: hidden;
#     width: 100%;
#     z-index: 10000;
#     transition: visibility 0s linear 0.218s, background-color 0.218s;
# }
# #spch.spch .close-button {
#         background-position: 0 0;
#         width: 24px;
#         height: 24px;
#         border: none;
#         cursor: pointer;
#         right: 0;
#         margin: 20px;
#         padding: 0;
#         position: absolute;
#         top: 0;
#         z-index: 10;
#         opacity: 0.8;
#     }
# #spch.spch .close-button:hover {
#             opacity: 1;
#         }
# #spch.spch .spchc {
#         display: block;
#         height: 97px;
#         pointer-events: none;
#     }
# #spch.spch .spchc .inner-container {
#             width: 100%;
#             height: 100%;
#             opacity: 0.1;
#             pointer-events: none;
#             transition: opacity 0.318s ease-in;
#         }
# #spch.spch .spchc .inner-container .spch-control {
#                 display: inline-block;
#             }
# #spch.spch .spchc .inner-container .text-container {
#                 float: left;
#                 height: 91px;
#                 overflow: hidden;
#                 margin: 3px 0;
#                 pointer-events: none;
#                 width: calc(50% - 48.5px);
#             }
# #spch.spch .spchc .inner-container .text-container p {
#                     display: table-cell;
#                     vertical-align: middle;
#                     width: 550px;
#                     height: 97px;
#                 }
# #spch.spch .spchc .inner-container .text-container .spcht {
#                     font-weight: normal;
#                     color: #6e7780;
#                     line-height: normal;
#                     opacity: 0;
#                     pointer-events: none;
#                     text-align: left;
#                     -webkit-font-smoothing: antialiased;
#                     transition: opacity 0.1s ease-in, margin-left 0.5s ease-in, top 0s linear 0.218s;
#                 }
# #spch.spch .spchc .inner-container .text-container .spcht.hide {
#                         display: none;
#                     }
# #spch.spch .spchc .inner-container .text-container #spcht-retry {
#                     color: #0f69ff;
#                     cursor: pointer;
#                     pointer-events: auto;
#                 }
# #spch.spch .spchc .inner-container .button-container {
#                 pointer-events: none;
#                 position: relative;
#                 transition: transform 0.218s, opacity 0.218s ease-in;
#             }
# #spch.spch .spchc .inner-container .button-container .button {
#                     background-color: #fff;
#                     border: 1px solid #eee;
#                     border-radius: 100%;
#                     bottom: 0;
#                     box-shadow: 0 2px 5px rgb(0 0 0 / 10%);
#                     cursor: pointer;
#                     display: inline-block;
#                     left: 0;
#                     opacity: 0;
#                     pointer-events: none;
#                     position: absolute;
#                     right: 0;
#                     top: 0;
#                     transition: background-color 0.218s, border 0.218s, box-shadow 0.218s;
#                 }
# #spch.spch .spchc .inner-container .button-container .button .microphone {
#                         background-position: 0 -24px;
#                         width: 41px;
#                         height: 41px;
#                         left: 27px;
#                         pointer-events: none;
#                         position: absolute;
#                         top: 27px;
#                         transform: scale(1);
#                     }
# #spch.spch .spchc .inner-container .button-container.listening .ripple {
#                         position: absolute;
#                         width: 136px;
#                         height: 136px;
#                         z-index: -1;
#                         left: 50%;
#                         top: 50%;
#                         opacity: 0;
#                         margin: -70px 0 0 -70px;
#                         border-radius: 100px;
#                         animation: ripple 3.3s infinite;
#                         background-color: #fff !important;
#                         border: 2px solid #e0e4e9;
#                     }
# #spch.spch .spchc .inner-container .button-container.listening .ripple:nth-child(2) {
#                             animation-delay: 1.1s;
#                         }
# #spch.spch .spchc .inner-container .button-container.listening .ripple:nth-child(3) {
#                             animation-delay: 2.2s;
#                         }
# #spch.spch .spchc .inner-container .button-container.speaking .button {
#                         background-color: #0f69ff;
#                     }
# #spch.spch .spchc .inner-container .button-container.speaking .button .microphone {
#                             background-position: 0 -65px;
#                             width: 40px;
#                             height: 40px;
#                             pointer-events: none;
#                             position: absolute;
#                             transform: scale(1);
#                         }
# #spch.spch .spchc .inner-container .button-container.speaking .ripple {
#                         background-size: 114px;
#                         position: absolute;
#                         width: 114px;
#                         height: 114px;
#                         z-index: -1;
#                         left: 50%;
#                         top: 50%;
#                         margin: -57px 0 0 -57px;
#                         animation: speakingRipple1 2s infinite;
#                     }
# #spch.spch .spchc .inner-container .button-container.speaking .ripple:nth-child(2) {
#                             background-size: 123px;
#                             width: 123px;
#                             height: 123px;
#                             margin: -62px 0 0 -62px;
#                             animation: speakingRipple2 2s infinite;
#                         }
# #spch.spch .spchc .inner-container .button-container.speaking .ripple:nth-child(3) {
#                             background-size: 136px;
#                             width: 136px;
#                             height: 136px;
#                             margin: -68px 0 0 -68px;
#                             animation: speakingRipple3 2s infinite;
#                         }
# #spch.spch .spcho {
#         background-image: linear-gradient(to bottom, rgb(255 255 255) 50%, rgb(255 255 255 / 0%) 99%);
#         display: block;
#         min-width: 100%;
#         text-align: center;
#         top: 145px;
#         padding-bottom: 71px;
#         pointer-events: auto;
#     }
# #spch.spch .spcho #spch-trending {
#             animation: fadeIn 1s forwards;
#             opacity: 0;
#         }
# #spch.spch .spcho #spch-trending .trending {
#                 color: #6e7780;
#                 display: inline-block;
#                 font-size: 16px;
#             }
# #spch.spch .spcho #spch-trending #trending-label {
#                 font-weight: bold;
#                 margin: 5px;
#             }
# #spch.spch .spcho #spch-trending.hide {
#                 display: none;
#             }
# #spch.spch.s2tb .spchc, #spch.spch.s2tb-h .spchc {
#             background: #fff;
#             box-sizing: border-box;
#             box-shadow: 0 2px 6px rgb(0 0 0 / 20%);
#             height: auto;
#             margin: 0;
#             min-width: 100%;
#             overflow: hidden;
#             padding: 24px 115px;
#         }
# #spch.spch.s2tb .spchc .inner-container, #spch.spch.s2tb-h .spchc .inner-container {
#                 opacity: 1;
#                 transition: opacity 0.318s ease-in;
#             }
# #spch.spch.s2tb .spchc .inner-container .text-container, #spch.spch.s2tb-h .spchc .inner-container .text-container {
#                     position: relative;
#                 }
# #spch.spch.s2tb {
#         background: rgb(255 255 255 / 0%);
#         opacity: 1;
#         visibility: visible;
#         transition-delay: 0s;
#     }
# #spch.spch.s2tb .spchc .inner-container .button-container {
#                     transform: scale(1);
#                     height: 97px;
#                     right: 0;
#                     top: 0;
#                     width: 97px;
#                 }
# #spch.spch.s2tb .spchc .inner-container .button-container .button {
#                         opacity: 1;
#                         pointer-events: auto;
#                         position: absolute;
#                         transform: scale(1);
#                         transition-delay: 0;
#                     }
# #spch.spch.s2tb .spchc .inner-container .text-container .spcht {
#                         font-size: 24px;
#                         margin-left: 0;
#                         opacity: 1;
#                         transition: opacity 0.5s ease-out, margin-left 0.5s ease-out;
#                     }
# #spch.spch.s2tb #spch-overlay {
#             -webkit-backdrop-filter: blur(10px);
#                     backdrop-filter: blur(10px);
#             background-color: #fff;
#             height: 100%;
#             opacity: 0.9;
#             position: absolute;
#             top: 149px;
#
#             /* spchc's height */
#             width: 100%;
#         }
# #spch.spch.disable-blur-overlay #spch-overlay {
#             background-color: transparent;
#
#             /* stylelint-disable-next-line property-no-vendor-prefix */
#             -webkit-backdrop-filter: none;
#             backdrop-filter: none;
#         }
# #spch.spch.disable-blur-overlay .spcho {
#             height: 27px;
#             padding-bottom: 20px;
#             background: #fff;
#             background-image: none;
#
#             /* stylelint-disable-next-line property-no-vendor-prefix */
#
#             /* stylelint-disable-next-line property-no-vendor-prefix */
#             box-shadow: 0 8px 6px -6px rgb(0 0 0 / 20%);
#         }
# #spch.spch.s2tb-h {
#         background: rgb(255 255 255 / 0%);
#         opacity: 0;
#         visibility: hidden;
#     }
#
# /* stylelint-disable-next-line keyframes-name-pattern */
# @keyframes fadeIn {
#     0% {
#         opacity: 0;
#     }
#
#     100% {
#         opacity: 1;
#     }
# }
#
# /* stylelint-disable-next-line keyframes-name-pattern */
# @keyframes ripple {
#     0% {
#         opacity: 1;
#         transform: scale(0.7);
#     }
#
#     100% {
#         opacity: 0;
#         transform: scale(1);
#     }
# }
#
# /* stylelint-disable-next-line keyframes-name-pattern */
# @keyframes speakingRipple1 {
#     0%,
#     100% {
#         background-image: url("https://s.yimg.com/pv/static/img/ripple1-1-202105260611.png");
#     }
#
#     25%,
#     75% {
#         background-image: url("https://s.yimg.com/pv/static/img/ripple1-2-202105260611.png");
#         transform: scale(1.1);
#     }
#
#     50% {
#         background-image: url("https://s.yimg.com/pv/static/img/ripple1-3-202105260611.png");
#         transform: scale(0.9);
#     }
# }
#
# /* stylelint-disable-next-line keyframes-name-pattern */
# @keyframes speakingRipple2 {
#     0%,
#     100% {
#         background-image: none;
#     }
#
#     25%,
#     75% {
#         background-image: url("https://s.yimg.com/pv/static/img/ripple2-2-202105260611.png");
#         transform: scale(1.1);
#     }
#
#     50% {
#         background-image: url("https://s.yimg.com/pv/static/img/ripple2-3-202105260611.png");
#         transform: scale(0.9);
#     }
# }
#
# /* stylelint-disable-next-line keyframes-name-pattern */
# @keyframes speakingRipple3 {
#     0%,
#     25%,
#     75%,
#     100% {
#         background-image: none;
#     }
#
#     50% {
#         background-image: url("https://s.yimg.com/pv/static/img/ripple3-3-202105260611.png");
#         transform: scale(0.9);
#     }
# }
# </style><style title="ybar_nav_interim"></style><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/nodes/0.Br5Sb6wz.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/chunks/scheduler._9po1iZb.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/chunks/index.vXbxsOYb.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/nodes/1.C5_gzv4b.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/chunks/stores.BDW1kbcO.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/chunks/43.rM6FwEuz.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/chunks/control.CYgJF_JY.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/nodes/2.BZTHYgaL.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/chunks/commonUtil.B1_Ohdkg.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/chunks/PageProgressBar.B-09kLXh.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/chunks/device.BBvd6b_1.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/chunks/preload-helper.D6kgxu3v.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/chunks/globals.D0QH3NT1.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/chunks/i13nUtil.C-uBpR7k.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/chunks/index.rV6zwFgL.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/chunks/each.BRmufY_q.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/chunks/spread.CgU5AtxT.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/chunks/Header.DrF_e3Te.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/chunks/RMP.DnljWIW7.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/chunks/Link.2FMGUQyk.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/chunks/Icon.B8K5mfd_.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/chunks/cookieUtil.cIaVHwG2.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/chunks/Button.C04JjCTs.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/chunks/close.C3ug6nNR.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/chunks/Typography.DjEFJyZ5.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/nodes/13.DMc2OXru.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/chunks/Dock.COsx5CI3.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/chunks/initializeDock.iEbUqKgf.js"><link rel="modulepreload" as="script" crossorigin="" href="https://finance.yahoo.com/assets/_app/immutable/chunks/logUtil.E7DzZb7c.js"><link rel="modulepreload" as="script" crossorigin="" href="htt ...
# 	width: 100%;
# 	height: auto;
# 	visibility: inherit !important;
# }
# .sc-carousel .videoCube.videoCube.videoCube {
#   visibility: inherit !important;
# }
# .sc-carousel.sc-carousel .videoCube.thumbnail_start .videoCube_aspect {
# 	padding-bottom: 52.356%;
# }</style><style>@import url('//cdn.taboola.com/static/22/228515c2-9c18-491a-a142-95df43dd9630.css')</style><style>@import url('//cdn.taboola.com/static/impl/css/GTAmerica_2024-03-27.css')</style><style>@import url('//cdn.taboola.com/static/6b/6b91a1bc-8217-4d34-9774-28dc8fd0cd05.css')</style><style>@import url('//cdn.taboola.com/static/impl/css/yahoo_cr3_beta.css')</style><style>@import url('//cdn.taboola.com/static/22/228515c2-9c18-491a-a142-95df43dd9630.css')</style><style>@import url('//cdn.taboola.com/static/impl/css/GTAmerica_2024-03-27.css')</style><style>@import url('//cdn.taboola.com/static/6b/6b91a1bc-8217-4d34-9774-28dc8fd0cd05.css')</style><style>@import url('//cdn.taboola.com/static/impl/css/yahoo_cr3_beta.css')</style><style>@import url('//cdn.taboola.com/static/22/228515c2-9c18-491a-a142-95df43dd9630.css')</style><style>@import url('//cdn.taboola.com/static/impl/css/GTAmerica_2024-03-27.css')</style><style>@import url('//cdn.taboola.com/static/6b/6b91a1bc-8217-4d34-9774-28dc8fd0cd05.css')</style><style>@import url('//cdn.taboola.com/static/impl/css/yahoo_cr3_beta.css')</style><style>@import url('//cdn.taboola.com/static/22/228515c2-9c18-491a-a142-95df43dd9630.css')</style><style>@import url('//cdn.taboola.com/static/impl/css/GTAmerica_2024-03-27.css')</style><style>@import url('//cdn.taboola.com/static/6b/6b91a1bc-8217-4d34-9774-28dc8fd0cd05.css')</style><style>@import url('//cdn.taboola.com/static/impl/css/yahoo_cr3_beta.css')</style></head>
#
#     <body id="atomic">
#         <div id="sda-E2E" class="sdaContainer tw-m-0 tw-py-2 sm:tw-py-4 md:tw-py-6 tw-flex tw-justify-center hideOnPrint" data-google-query-id="CKPdy52vxokDFY30EQgdPmgnyg" style="min-height: 250px;"><div id="google_ads_iframe_/22888152279/us/yfin/screen/dt/us_yfin_screen_dt_top_center_0__container__" style="border: 0pt none; display: inline-block; width: 970px; height: 250px;"><iframe frameborder="0" src="https://4907d402704196a38aadb2fce113ae32.safeframe.googlesyndication.com/safeframe/1-0-40/html/container.html" id="google_ads_iframe_/22888152279/us/yfin/screen/dt/us_yfin_screen_dt_top_center_0" title="3rd party ad content" name="" scrolling="no" marginwidth="0" marginheight="0" width="970" height="250" data-is-safeframe="true" sandbox="allow-forms allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" allow="private-state-token-redemption;attribution-reporting" aria-label="Advertisement" tabindex="0" style="border: 0px; vertical-align: bottom;" data-google-container-id="1" data-load-complete="true"></iframe></div></div>
#         <div id="svelte"><script type="module">if (!window._nimbus){window._nimbus={appState:{}};}window._nimbus.appState.debug={"headers":{},"liveConfig":{},"perf":[],"start":0,"content":[]};</script>   <script type="application/json" id="fin-trending-tickers">[{"fullExchangeName":"NasdaqGS","symbol":"SMCI","gmtOffSetMilliseconds":-18000000,"language":"en-US","regularMarketTime":{"raw":1730840400,"fmt":"4:00PM EST"},"regularMarketChangePercent":{"raw":6.415674,"fmt":"6.42%"},"quoteType":"EQUITY","typeDisp":"Equity","tradeable":false,"regularMarketPreviousClose":{"raw":26.03,"fmt":"26.03"},"exchangeTimezoneName":"America/New_York","trendingScore":{"raw":144.2871957608423,"fmt":"14,428.72%"},"regularMarketChange":{"raw":1.6700001,"fmt":"1.67"},"cryptoTradeable":false,"exchangeDataDelayedBy":0,"firstTradeDateMilliseconds":1175175000000,"exchangeTimezoneShortName":"EST","hasPrePostMarketData":true,"marketState":"POST","regularMarketPrice":{"raw":27.7,"fmt":"27.70"},"customPriceAlertConfidence":"HIGH","market":"us_market","quoteSourceName":"Delayed Quote","priceHint":2,"sourceInterval":15,"exchange":"NMS","shortName":"Super Micro Computer, Inc.","region":"US","triggerable":true,"longName":"Super Micro Computer, Inc."},{"fullExchangeName":"NasdaqGM","symbol":"DJT","gmtOffSetMilliseconds":-18000000,"language":"en-US","regularMarketTime":{"raw":1730840401,"fmt":"4:00PM EST"},"regularMarketChangePercent":{"raw":-1.1648269,"fmt":"-1.16%"},"quoteType":"EQUITY","typeDisp":"Equity","tradeable":false,"regularMarketPreviousClose":{"raw":34.34,"fmt":"34.34"},"exchangeTimezoneName":"America/New_York","trendingScore":{"raw":91.8237162066082,"fmt":"9,182.37%"},"regularMarketChange":{"raw":-0.40000153,"fmt":"-0.40"},"cryptoTradeable":false,"exchangeDataDelayedBy":0,"firstTradeDateMilliseconds":1633008600000,"exchangeTimezoneShortName":"EST","hasPrePostMarketData":true,"marketState":"POST","regularMarketPrice":{"raw":33.94,"fmt":"33.94"},"customPriceAlertConfidence":"LOW","market":"us_market","quoteSourceName":"Delayed Quote","priceHint":2,"sourceInterval":15,"exchange":"NGM","shortName":"Trump Media & Technology Group ","region":"US","triggerable":false,"longName":"Trump Media & Technology Group Corp."},{"fullExchangeName":"NasdaqGM","symbol":"ZCAR","gmtOffSetMilliseconds":-18000000,"language":"en-US","regularMarketTime":{"raw":1730840400,"fmt":"4:00PM EST"},"regularMarketChangePercent":{"raw":227.54343,"fmt":"227.54%"},"quoteType":"EQUITY","typeDisp":"Equity","tradeable":false,"regularMarketPreviousClose":{"raw":4.03,"fmt":"4.03"},"exchangeTimezoneName":"America/New_York","trendingScore":{"raw":46.68591061927507,"fmt":"4,668.59%"},"regularMarketChange":{"raw":9.17,"fmt":"9.17"},"cryptoTradeable":false,"exchangeDataDelayedBy":0,"firstTradeDateMilliseconds":1641306600000,"exchangeTimezoneShortName":"EST","hasPrePostMarketData":true,"marketState":"POST","regularMarketPrice":{"raw":13.2,"fmt":"13.20"},"customPriceAlertConfidence":"LOW","market":"us_market","quoteSourceName":"Delayed Quote","priceHint":2,"sourceInterval":15,"exchange":"NGM","shortName":"Zoomcar Holdings, Inc.","region":"US","triggerable":false,"longName":"Zoomcar Holdings, Inc."},{"fullExchangeName":"NYSE","symbol":"RDDT","gmtOffSetMilliseconds":-18000000,"language":"en-US","regularMarketTime":{"raw":1730840445,"fmt":"4:00PM EST"},"regularMarketChangePercent":{"raw":12.4186,"fmt":"12.42%"},"quoteType":"EQUITY","typeDisp":"Equity","tradeable":false,"regularMarketPreviousClose":{"raw":109.03,"fmt":"109.03"},"exchangeTimezoneName":"America/New_York","trendingScore":{"raw":39.706026739173666,"fmt":"3,970.60%"},"regularMarketChange":{"raw":13.54,"fmt":"13.54"},"cryptoTradeable":false,"exchangeDataDelayedBy":0,"firstTradeDateMilliseconds":1711114200000,"exchangeTimezoneShortName":"EST","hasPrePostMarketData":true,"marketState":"POST","regularMarketPrice":{"raw":122.57,"fmt":"122.57"},"customPriceAlertConfidence":"LOW","market":"us_market","quoteSourceName":"Delayed Quote","priceHint":2,"s ...
# /*! Copyright 2017 Yahoo Holdings, Inc. All rights reserved. */
# ...
#         <script src="https://consent.cmp.oath.com/version/6.4.1/cmp.js" defer=""></script><script src="https://s.yimg.com/oa/consent-1.0.383.js" defer=""></script><script src="https://s.yimg.com/zz/combo?s:aaq/vzm/cs_1.6.6.js" defer=""></script><script>(function(){window._comscore = window._comscore||[];window._comscore.push({});window.COMSCORE?.purge();})();
#     </script><script src="https://s.yimg.com/uc/sf/0.1.495/js/safe.modern.js" defer=""></script><script type="module">
#     (function(win) {
#         win.addEventListener && win.addEventListener("DOMContentLoaded", function () {
#             var s = win.document.createElement("script");
#             s.async = true;
#             s.defer = true;
#             s.src = "https://s.yimg.com/cx/pv/perf-vitals_3.5.0.js";
#             win.document.body.appendChild(s);
#         });
#     })(window);</script>
#
#
# <script src="https://s.yimg.com/uc/finance/webcore/js/streamer.248f993752a5b05fef83.mjs" type="text/javascript" async="true"></script><div class="_yb_e1uxm0 _yb_ed0cmg"></div><div class="permission-guide hide" id="spchp">
#                 <div class="close-button" id="spchpx"></div>
#                 <div class="guide">
#                     <div class="microphone">
#                         <div class="sprite"></div>
#                     </div>
#                     <div class="guide-text">
#                         <div class="title">Waiting for permission</div>
#                         <div class="text">Allow microphone access to enable voice search</div>
#                     </div>
#                 </div>
#             </div><div class="spch s2tb-h" id="spch">
#                 <div class="spch-overlay" id="spch-overlay"></div>
#                 <div class="close-button" id="spchx"></div>
#                 <div class="spchc">
#                     <div class="inner-container">
#                         <div class="button-container spch-control" id="spchbc">
#                             <span class="button" id="spchbc-btn">
#                                 <div class="microphone"></div>
#                             </span>
#                             <span class="ripple"></span>
#                             <span class="ripple"></span>
#                             <span class="ripple"></span>
#                         </div>
#                         <div class="text-container spch-control">
#                             <p>
#                                 <span class="spcht" id="spcht"></span>
#                                 <span></span>
#                                 <span class="spcht" id="spcht-retry">Try again.</span>
#                             </p>
#                         </div>
#                     </div>
#                 </div>
frameborder="0" allowtransparency="true" marginheight="0" marginwidth="0" width="0" hspace="0" vspace="0" height="0" style="height:0px;width:0px;display:none;" scrolling="no" src="https://pixel.rubiconproject.com/exchange/sync.php?p=pbs-yahoo-exchange&amp;gdpr=0&amp;gdpr_consent=&amp;us_privacy=1---">
#     </iframe></html>

# %% [markdown]
# # Laboratory Exercise - Run Mode (8 points)

# %% [markdown]
# In this laboratory assignment, the goal is to perform web scraping using **Selenium** on the website https://finance.yahoo.com/crypto. The task includes the extraction of **Cryptocurrency names** and their **price** and **market cap**. Following this data extraction, you will construct a data frame to organize the collected data. Finally, you are expected to generate a histogram to provide a visual representation of the distribution of the prices.

# %% [markdown]
# ## Hints
# - To navigate to a specific page with a given URL, use the `browser.get(url)` method.
# - When selecting a single element, use `browser.find_element`, and for multiple elements, use `browser.find_elements`. Both of these functions take two arguments. The first specifies the attribute used to locate the element on the web page, and the second specifies the value of that attribute.
# - The `By` class is used to specify which attribute is used to locate elements on a page. These are the various ways the attributes are used to locate elements on a page: `By.ID`, `By.NAME`, `By.TAG_NAME`, `BY.CLASS_NAME`, `By.CSS_SELECTOR`, etc.
# - For more details, check the documentation (https://selenium-python.readthedocs.io/locating-elements.html).

# %% [markdown]
# ## Solution

# %%
# Write your code here.
table_rows = browser.find_element(By.CLASS_NAME, "markets-table").find_elements(By.CLASS_NAME, 'row')
# for row in table_rows:
#     print(row.text)
crypto = dict()
row_elements = table_rows[0].find_elements(By.CLASS_NAME, 'cell')
# for el in row_elements:
#     print(el.text)
crypto['name'] = row_elements[1].text
crypto['price'] = row_elements[3].text
crypto['market-cap'] = row_elements[6].text
crypto
# Out:
# {'name': 'Bitcoin USD', 'price': '69,737.59', 'market-cap': '1.379T'}

# %%
# Add as many code boxes as you need.
crypto_list = []

for row in table_rows:
    crypto = dict()
    row_elements = row.find_elements(By.CLASS_NAME, 'cell')
    crypto['name'] = row_elements[1].text
    crypto['price'] = float(row_elements[3].text.replace(",", ""))
    crypto['market-cap'] = row_elements[6].text
    crypto_list.append(crypto)

crypto_list
# Out:
# [{'name': 'Bitcoin USD', 'price': 69737.59, 'market-cap': '1.379T'},
#  {'name': 'Ethereum USD', 'price': 2434.64, 'market-cap': '293.172B'},
#  {'name': 'Tether USDt USD', 'price': 1.0002, 'market-cap': '120.516B'},
#  {'name': 'BNB USD', 'price': 566.09, 'market-cap': '81.574B'},
#  {'name': 'Solana USD', 'price': 167.05, 'market-cap': '78.665B'},
#  {'name': 'USD Coin USD', 'price': 1.0, 'market-cap': '35.532B'},
#  {'name': 'XRP USD', 'price': 0.51446, 'market-cap': '29.257B'},
#  {'name': 'Dogecoin USD', 'price': 0.172074, 'market-cap': '25.238B'},
#  {'name': 'Lido Staked ETH USD', 'price': 2435.97, 'market-cap': '23.747B'},
#  {'name': 'Wrapped TRON USD', 'price': 0.160204, 'market-cap': '14.006B'},
#  {'name': 'TRON USD', 'price': 0.160267, 'market-cap': '13.854B'},
#  {'name': 'Toncoin USD', 'price': 4.7157, 'market-cap': '11.998B'},
#  {'name': 'Cardano USD', 'price': 0.334846, 'market-cap': '11.721B'},
#  {'name': 'Lido wstETH USD', 'price': 2877.24, 'market-cap': '10.802B'},
#  {'name': 'Shiba Inu USD', 'price': 1.8e-05, 'market-cap': '10.562B'},
#  {'name': 'Wrapped Bitcoin USD', 'price': 69578.84, 'market-cap': '10.228B'},
#  {'name': 'Avalanche USD', 'price': 24.07, 'market-cap': '9.801B'},
#  {'name': 'WETH USD', 'price': 2431.56, 'market-cap': '8.207B'},
#  {'name': 'Chainlink USD', 'price': 10.88, 'market-cap': '6.823B'},
#  {'name': 'Bitcoin Cash USD', 'price': 344.5, 'market-cap': '6.816B'},
#  {'name': 'Polkadot USD', 'price': 3.8721, 'market-cap': '5.866B'},
#  {'name': 'Sui USD', 'price': 2.0072, 'market-cap': '5.712B'},
#  {'name': 'USDS USD', 'price': 0.997064, 'market-cap': '5.599B'},
#  {'name': 'UNUS SED LEO USD', 'price': 6.0451, 'market-cap': '5.592B'},
#  {'name': 'Dai USD', 'price': 1.0, 'market-cap': '5.366B'}]

# %%
df = pd.DataFrame(crypto_list)
df['price'] = pd.to_numeric(df['price'], errors='coerce')  
df
# Out:
#                    name         price market-cap
# 0           Bitcoin USD  69737.590000     1.379T
# 1          Ethereum USD   2434.640000   293.172B
# 2       Tether USDt USD      1.000200   120.516B
# 3               BNB USD    566.090000    81.574B
# 4            Solana USD    167.050000    78.665B
# 5          USD Coin USD      1.000000    35.532B
# 6               XRP USD      0.514460    29.257B
# 7          Dogecoin USD      0.172074    25.238B
# 8   Lido Staked ETH USD   2435.970000    23.747B
# 9      Wrapped TRON USD      0.160204    14.006B
# 10             TRON USD      0.160267    13.854B
# 11          Toncoin USD      4.715700    11.998B
# 12          Cardano USD      0.334846    11.721B
# 13      Lido wstETH USD   2877.240000    10.802B
# 14        Shiba Inu USD      0.000018    10.562B
# 15  Wrapped Bitcoin USD  69578.840000    10.228B
# 16        Avalanche USD     24.070000     9.801B
# 17             WETH USD   2431.560000     8.207B
# 18        Chainlink USD     10.880000     6.823B
# 19     Bitcoin Cash USD    344.500000     6.816B
# 20         Polkadot USD      3.872100     5.866B
# 21              Sui USD      2.007200     5.712B
# 22             USDS USD      0.997064     5.599B
# 23     UNUS SED LEO USD      6.045100     5.592B
# 24              Dai USD      1.000000     5.366B

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
plt.hist(df['price'], bins=20, color='skyblue', edgecolor='black')

plt.title('Cryptocurrency Price Distribution')
plt.xlabel('Price (USD)')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# # Laboratory Exercise - Bonus Task (+ 2 points)

# %% [markdown]
# The additional task involves clicking on the symbol for BTC-USD and on the new page that appears click on the **Historical data**. You will extract the prices and market caps for the BTC-USD only, and make line plot for the price data.

# %% [markdown]
# ## Hints
# - To populate an input field (`input_field`) with some `text` use `input_field.send_keys(text)`.
# - To click on a specific `element` on a web page use `element.click()`.

# %% [markdown]
# ## Solution

# %%
# Write your code here.
input_field = browser.find_element(By.ID, 'ybar-sbq')
input_field.send_keys("BTC-USD")

# %%
button = browser.find_element(By.ID, "ybar-search")
button.click()

# %%
historical_data_button = browser.find_element(By.CLASS_NAME, 'nav-list').find_elements(By.CLASS_NAME, 'yf-1e6z5da')[12]
historical_data_button.click()
